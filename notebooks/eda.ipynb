# %% [markdown]
# # Patient Engagement EDA
#
# Exploratory analysis for patient journey, retention, engagement, and treatment cost.

# %%
import pandas as pd
df = pd.read_csv('../data/patient_engagement.csv', parse_dates=['Journey Date'])
df.head()

# %%
df.info()
df.describe(include='all')
