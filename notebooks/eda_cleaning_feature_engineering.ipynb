# %% [markdown]
# # EDA Cleaning Feature Engineering
# Patient Engagement & Outcomes Dashboard

# %%
import pandas as pd
df = pd.read_csv('../data/patient_engagement.csv')
df.head()

# %%
df.shape, df.info()

# %%
df.isna().sum().sort_values(ascending=False)

# %%
df.duplicated().sum()

# %%
df['Journey Date'] = pd.to_datetime(df['Journey Date'], errors='coerce')
df.columns = [c.strip().lower().replace(' ', '_').replace('-', '_') for c in df.columns]
df.head()

# %% [markdown]
# ## Insight Summary
# Patient engagement is strongest early in the journey, but D30 retention and treatment completion should be improved with targeted follow-up.
